# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sakshi987123/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/sakshi987123/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 125 (delta 39), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 1.85 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship

# %%
import os
print(os.listdir())
# Out:
# ['notebooks', 'work', 'AGENTS.md', 'skills', 'DATA_USE.md', 'scripts', '.github', 'LICENSE', '.gitignore', 'outputs', 'CLAUDE.md', 'data', 'README.md', 'submission', '.git', 'GUIDE.md', 'SETUP.md', 'requirements.txt', 'docs']

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My Lane as an ML Task
#
# **Lane:** Ranking Signal Analysis
#
# **ML Task Type:** Ranking
#
# The goal of this project is to analyze multiple ranking-related signals and score pages based on their likelihood of achieving better search performance. Instead of making a simple yes/no prediction, the model ranks pages according to their optimization potential so that the SEO team can prioritize improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The dataset does not contain a direct "ranking quality" label, so I will use search performance metrics such as average position, CTR, and impressions as proxy indicators.
#
# The target is to identify pages that have stronger ranking signals and better search visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# A successful model should correctly prioritize pages that have stronger ranking signals and higher search visibility.
#
# The usefulness of the ranked recommendations and their ability to support SEO decision making will be the primary measure of success.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## Unit of Analysis
#
# Each row in the dataset represents one web page.
#
# For each page, the dataset contains ranking-related information such as search volume, impressions, click-through rate (CTR), and average search position. These features help analyze which signals are associated with better search performance.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

columns = [
    "content_id",
    "search_volume",
    "impressions_90d",
    "ctr",
    "avg_position"
]

print("One row represents one web page.\n")

df[columns].head()
# Out:
# One row represents one web page.
#              content_id  search_volume  impressions_90d   ctr  avg_position
# 0  content_304f48230142           10.0             3803  0.76          10.6
# 1  content_a1fb4e703a9e           90.0            15320  0.05          20.3
# 2  content_9aa793d4d895            0.0            12581  0.09          36.5
# 3  content_331d6c4de07b           10.0            11751  0.49           6.2
# 4  content_d99b7a2d90ca            0.0            19140  0.13          44.0

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# A fixed rule, such as selecting pages only by search volume or only by CTR, ignores the interaction between multiple ranking signals.
#
# Machine learning can analyze several features together, identify complex patterns, and provide more useful ranking recommendations than a single fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
